# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from dython.nominal import associations, correlation_ratio, cramers_v
# Out:
# /home/ronald/anaconda3/envs/tp_analisis_de_datos/lib/python3.11/site-packages/dython/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution

# %%
def entropy(series):
    probs = series.value_counts(normalize=True)
    probs = probs[probs > 0]
    return -(probs * np.log2(probs)).sum()

# %%
# Leemos el csv, es un archivo grande
df = pd.read_csv("data/GEDEvent_v25_1.csv", low_memory=False)
df.head()
# Out:
#        id               relid  year  active_year code_status  \
# 0  244657  IRQ-2017-1-524-322  2017         True       Clear
# 1  412700  IRQ-2021-1-524-145  2021         True       Clear
# 2  413023  IRQ-2021-1-524-143  2021         True       Clear
# 3  412909  IRQ-2021-1-524-144  2021         True       Clear
# 4  132140    AFG-1989-1-411-2  1989         True       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                 1               259              259
# 1                 1               259              259
# 2                 1               259              259
# 3                 1               259              259
# 4                 1               333              333
#
#              conflict_name  dyad_dset_id  ...                 date_end  \
# 0         Iraq: Government           524  ...  2017-07-31 00:00:00.000
# 1         Iraq: Government           524  ...  2021-08-26 00:00:00.000
# 2         Iraq: Government           524  ...  2021-08-28 00:00:00.000
# 3         Iraq: Government           524  ...  2021-08-29 00:00:00.000
# 4  Afghanistan: Government           724  ...  1989-01-13 00:00:00.000
#
#   deaths_a  deaths_b  deaths_civilians deaths_unknown  best  high  low  gwnoa  \
# 0        0         4                 0              2     6     6    6    645
# 1       13         1               141             28   183   184  171    645
# 2        0         2                 0              0     2     3    0    645
# 3        0         0                10              0    10    10    9    645
# 4        6         0                 0              0     6     6    6    700
#
#   gwnob
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 49 columns]

# %%
# Eliminamos duplicados y contamos filas
df.drop_duplicates(inplace=True)
print(f"Número de filas: {df.shape[0]}")
# Out:
# Número de filas: 385918

# %%
df_resumen = pd.DataFrame({
    'variable_name': df.columns,
    'dtype': df.dtypes.astype(str),
    'no nulos': df.count(),
    'unicos': df.nunique(),
    'unicos_%': (df.nunique()/df.count()*100).round(0).astype(int),
    'nulos': df.isna().sum(),
    'nulos_%': (df.isna().mean() * 100).round(0).astype(int)

})
df_resumen.reset_index(drop=True, inplace=True)
df_resumen
# Out:
#         variable_name    dtype  no nulos  unicos  unicos_%   nulos  nulos_%
# 0                  id    int64    385918  385918       100       0        0
# 1               relid   object    385918  385918       100       0        0
# 2                year    int64    385918      36         0       0        0
# 3         active_year     bool    385918       2         0       0        0
# 4         code_status   object    385918       1         0       0        0
# 5    type_of_violence    int64    385918       3         0       0        0
# 6    conflict_dset_id    int64    385918    1484         0       0        0
# 7     conflict_new_id    int64    385918    1531         0       0        0
# 8       conflict_name   object    385918    1529         0       0        0
# 9        dyad_dset_id    int64    385918    1740         0       0        0
# 10        dyad_new_id    int64    385918    1775         0       0        0
# 11          dyad_name   object    385918    1771         0       0        0
# 12     side_a_dset_id    int64    385918     970         0       0        0
# 13      side_a_new_id    int64    385918     970         0       0        0
# 14             side_a   object    385918     966         0       0        0
# 15     side_b_dset_id    int64    385918     967         0       0        0
# 16      side_b_new_id    int64    385918     967         0       0        0
# 17             side_b   object    385918     959         0       0        0
# 18  number_of_sources    int64    385918      54         0       0        0
# 19     source_article   object    385917  255147        66       1        0
# 20      source_office   object    288005   24027         8   97913       25
# 21        source_date   object    288005   48785        17   97913       25
# 22    source_headline   object    288000  185443        64   97918       25
# 23    source_original   object    341674   57447        17   44244       11
# 24         where_prec    int64    385918       7         0       0        0
# 25  where_coordinates   object    385918   54511        14       0        0
# 26  where_description   object    375675  224241        60   10243        3
# 27              adm_1   object    366371    1682         0   19547        5
# 28              adm_2   object    315941    9366         3   69977       18
# 29           latitude  float64    385918   52516        14       0        0
# 30          longitude  float64    385918   53330        14       0        0
# 31           geom_wkt   object    385918   56378        15       0        0
# 32       priogrid_gid    int64    385918    7765         2       0        0
# 33            country   object    385918     124         0       0        0
# 34         country_id    int64    385918     124         0       0        0
# 35             region   object    385918       5         0       0        0
# 36      event_clarity    int64    385918       2         0       0        0
# 37          date_prec    int64    385918       5         0       0        0
# 38         date_start   object    385918   13142         3       0        0
# 39           date_end   object    385918   13145         3       0        0
# 40           deaths_a    int64    385918     349         0       0        0
# 41           deaths_b    int64    385918     331         0       0        0
# 42   deaths_civilians    int64    385918     427         0       0        0
# 43     deaths_unknown    int64    385918     414         0       0        0
# 44               best    int64    385918     782         0       0        0
# 45               high    int64    385918     959         0       0        0
# 46                low    int64    385918     687         0       0        0
# 47              gwnoa   object    292507      97         0   93411       24
# 48              gwnob  float64     30256      15         0  355662       92

# %% [markdown]
# **Procedimiento de selección de variables**
#
# Para eliminar del dataset variables que no aportan información seguimos la siguiente secuecia:
# 1) Eliminamos los id de los casos individuales: [id] y [relid]
# 2) Eliminamos las variables que representan una versión alternativa de otra:\
#    [year] está implícita en [date_start]\
#    [conflict_dset_id], [conflict_new_id] son versiones de [conflict_name]\
#    [dyad_dset_id], [dyad_new_id] son versiones de [dyad_name]\
#    [side_a_dset_id], [side_a_new_id] y [gwnoa] son versiones de [side_a]\
#    [side_b_dset_id], [side_b_new_id] y [gwnob] son versiones de [side_b]\
#    [where_description] es un detalle de alta cardinalidad en texto abierto de [where_coordinates] (ej. Kabul international airport -> Kabul airport (Abbey gate entrance))\
#    [geom_wkt] es la concatenación de [longitude] y [latitude]\
#    [country_id] es otra versión de [country]\
# 4) Eliminamos variables con un valor único: [code_status]
# 5) Eliminamos variables con target leakage de [best]:\
#    [deaths_a], [deaths_b], [deaths_civilians], [deaths_unknown], [high] y [low] no estarían disponibles en un escenario real y conducen a [best]
# 6) Eliminamos variables de texto abierto vinculadas con las fuentes del los datos de mortalidad:\
#    [source_article], [source_office], [source_date], [source_headline], [source_original]

# %%
df.drop(columns=['id', 'relid', 'year', 'conflict_dset_id', 'conflict_new_id', 'dyad_dset_id', 'dyad_new_id', 'side_a_dset_id', 
                 'side_a_new_id', 'gwnoa', 'side_b_dset_id', 'side_b_new_id', 'gwnob', 'where_description', 'geom_wkt', 
                 'country_id', 'code_status', 'deaths_a', 'deaths_b', 'deaths_civilians', 'deaths_unknown', 'high', 'low',
                'source_article', 'source_office','source_date', 'source_headline','source_original'], inplace=True)

# %%
# Ajustamos las variables con fecha
df['date_start'] = pd.to_datetime(df['date_start'], errors='coerce')
df['date_end'] = pd.to_datetime(df['date_end'], errors='coerce')

# %%
# Mapeamos la variable nominal 'type_of_violence' a 1: state-based conflict 2: non-state conflict 3: one-sided violence
df["type_of_violence"] = df["type_of_violence"].map({1: "state-based conflict", 2: "non-state conflict", 3: "one-sided violence"}).astype("category")

# %%
# Ajustamos las variables categóricas
categoricas= ['active_year', 'type_of_violence','conflict_name', 'dyad_name', 'side_a', 'side_b', 'where_coordinates', 'adm_1', 'adm_2', 'priogrid_gid', 'country', 'region']
for categorica in categoricas:
    df[categorica] = df[categorica].astype("category")

# %%
entropias = df[categoricas].apply(entropy).round()
entropias = entropias.reindex(df.columns)
ent_max = df[categoricas].nunique().apply(lambda k: np.log2(k) if k > 0 else 0)
ent_max = ent_max.reindex(df.columns)

# Hacemos una tabla resumen con las características de cada variable, incluyendo la entropía de las variables 
df_resumen = pd.DataFrame({
    'variable_name': df.columns,
    'dtype': df.dtypes.astype(str),
    'no nulos': df.count(),
    'unicos': df.nunique(),
    'nulos': df.isna().sum(),
    'nulos_%': (df.isna().mean() * 100).round(0).astype(int),
    '% entropia': (entropias/ent_max*100).round()
})
df_resumen.reset_index(drop=True, inplace=True)
df_resumen
# Out:
#         variable_name           dtype  no nulos  unicos  nulos  nulos_%  \
# 0         active_year        category    385918       2      0        0
# 1    type_of_violence        category    385918       3      0        0
# 2       conflict_name        category    385918    1529      0        0
# 3           dyad_name        category    385918    1771      0        0
# 4              side_a        category    385918     966      0        0
# 5              side_b        category    385918     959      0        0
# 6   number_of_sources           int64    385918      54      0        0
# 7          where_prec           int64    385918       7      0        0
# 8   where_coordinates        category    385918   54511      0        0
# 9               adm_1        category    366371    1682  19547        5
# 10              adm_2        category    315941    9366  69977       18
# 11           latitude         float64    385918   52516      0        0
# 12          longitude         float64    385918   53330      0        0
# 13       priogrid_gid        category    385918    7765      0        0
# 14            country        category    385918     124      0        0
# 15             region        category    385918       5      0        0
# 16      event_clarity           int64    385918       2      0        0
# 17          date_prec           int64    385918       5      0        0
# 18         date_start  datetime64[ns]    385918   13142      0        0
# 19           date_end  datetime64[ns]    385918   13145      0        0
# 20               best           int64    385918     782      0        0
#
#     % entropia
# 0          0.0
# 1         63.0
# 2         57.0
# 3         65.0
# 4         61.0
# 5         50.0
# 6          NaN
# 7          NaN
# 8         83.0
# 9         75.0
# 10        76.0
# 11         NaN
# 12         NaN
# 13        77.0
# 14        72.0
# 15        86.0
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN

# %% [markdown]
# Analizamos correlaciones entre variables

# %%
cols = [
    'active_year', 'type_of_violence', 
    'conflict_name', 'dyad_name', 'side_a', 'side_b', 'number_of_sources',
    #'where_prec', 'where_coordinates', (las saco porque rompen la matriz de covarianza por cardinalidad)
    'adm_1', 'adm_2', 
    #'latitude', 'longitude', 'priogrid_gid', (las saco porque rompen la matriz de covarianza por cardinalidad)
    'country', 'region',
    'event_clarity', 'date_prec', 
    'date_start', 'date_end', 'best'
    ]

# %%
result = associations(
    df[cols],
    nominal_columns='auto',
    plot=False,
    nan_strategy='drop_samples'
)
# Out:
# /home/ronald/anaconda3/envs/tp_analisis_de_datos/lib/python3.11/site-packages/dython/nominal.py:632: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   lambda col: col.view(np.int64), axis=0

# %%
corr_matrix = result['corr']
plt.figure(figsize=(20, 12))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    annot_kws={"size": 7},
    linewidths=0.5
)
# Out:
# <Axes: >

# %%
variables=pd.read_csv("data/variables.csv", encoding="utf-8", sep=';')
variables
# Out:
#         variable_name                                        description  \
# 0                  id                     Identificador unico del evento
# 1               relid  Identificador interno del evento (cambia si el...
# 2                year                                     Ano del evento
# 3         active_year  True si el evento pertenece a un conflicto act...
# 4         code_status  Si el registro est  ok (clear) o si hay que ch...
# 5    type_of_violence  Tipo de violencia: 1. Conflicto entre estados,...
# 6    conflict_dset_id                            Identificador deprecado
# 7     conflict_new_id  Identificador único del conflicto (usar esto p...
# 8       conflict_name                               Nombre del conflicto
# 9        dyad_dset_id                            Identificador deprecado
# 10        dyad_new_id  Identificador unico de diadas participantes (u...
# 11          dyad_name  Nombre de los participantes de la diada en con...
# 12     side_a_dset_id  Identificador del participante A cuando la inf...
# 13      side_a_new_id             Identificador unico del participante A
# 14             side_a              Nombre del participante A en la diada
# 15     side_b_dset_id  Identificador del participante B cuando la inf...
# 16      side_b_new_id             Identificador unico del participante B
# 17             side_b              Nombre del participante B en la diada
# 18  number_of_sources  Cantidad de fuentes incorporadas con informaci...
# 19     source_article  Nombres, fechas y titulos de las fuentes emple...
# 20      source_office  Nombre de la organizacion que publica las fuen...
# 21        source_date  Fecha de publicacion de la fuente empleada (de...
# 22    source_headline                       Titulo de la fuente empleada
# 23    source_original  Persona u organizacion que dio informacion en ...
# 24         where_prec  Precision de las coordenadas y ubicacion asign...
# 25  where_coordinates      Nombre normalizado de la ubicacion del evento
# 26  where_description  Comentario (detalle) sobre where_coordinates (...
# 27              adm_1  Nombre de la division administrativa donde ocu...
# 28              adm_2  Nombre de la division administrativa donde ocu...
# 29           latitude                        Latitud en grados decimales
# 30          longitude                       Longitud en grados decimales
# 31           geom_wkt  Representacion en texto de la ubicacion del ev...
# 32       priogrid_gid  Asignacion de la ubicacion del evento a la gri...
# 33            country             Nombre del pais donde ocurre el evento
# 34         country_id      Identificador del pais donde ocurre el evento
# 35             region  Region (Africa, Americas, Asia, Europe, Middle...
# 36      event_clarity  1: High, 2: Low dependiendo de lo desagregado ...
# 37          date_prec  Precision de la fecha del evento (1. mayor - 5...
# 38         date_start               Fecha probable del inicio del evento
# 39           date_end                  Fecha probable del fin del evento
# 40           deaths_a  Muertes del lado A (0 si el evento es unilateral)
# 41           deaths_b  Muertes del lado B (0 si el evento es unilateral)
# 42   deaths_civilians                                    Muertes civiles
# 43     deaths_unknown                    Muertes con estatus desconocido
# 44               best  Mejor estimacion (mas probable) de muertes tot...
# 45               high               Maxima estimacion de muertes totales
# 46                low               Minima estimacion de muertes totales
# 47              gwnoa  Identificador alfabetico GW del participante A...
# 48              gwnob  Identificador alfabetico GW del participante B...
#
#     eliminate                                reason_to_eliminate
# 0        True                               Id de la observación
# 1        True                               Id de la observación
# 2        True                               Copia a [date_start]
# 3       False                                                NaN
# 4        True                Valor único (solo contiene 'clear')
# 5       False                                                NaN
# 6        True                            Copia a [conflict_name]
# 7        True                            Copia a [conflict_name]
# 8       False                                                NaN
# 9        True                                Copia a [dyad_name]
# 10       True                                Copia a [dyad_name]
# 11      False                                                NaN
# 12       True                                   Copia a [side_a]
# 13       True                                   Copia a [side_a]
# 14      False                                                NaN
# 15       True                                   Copia a [side_b]
# 16       True                                   Copia a [side_b]
# 17      False                                                NaN
# 18      False                                                NaN
# 19       True                 Datos de la fuentes que no aportan
# 20       True                 Datos de la fuentes que no aportan
# 21       True                 Datos de la fuentes que no aportan
# 22       True                 Datos de la fuentes que no aportan
# 23       True                 Datos de la fuentes que no aportan
# 24      False                                                NaN
# 25      False                                                NaN
# 26       True  Copia [where_coordinates] con detalles de text...
# 27      False                                                NaN
# 28      False                                                NaN
# 29      False                                                NaN
# 30      False                                                NaN
# 31       True         Concatenación de [longitude] y [latitude]
# 32       True    Sirve para enriquecer el dataset con info extra
# 33      False                                                NaN
# 34       True                                    Copia [country]
# 35      False                                                NaN
# 36      False                                                NaN
# 37      False                                                NaN
# 38      False                                                NaN
# 39      False                                                NaN
# 40       True                          Target leakeage de [best]
# 41       True                          Target leakeage de [best]
# 42       True                          Target leakeage de [best]
# 43       True                          Target leakeage de [best]
# 44      False                                                NaN
# 45       True                          Target leakeage de [best]
# 46       True                          Target leakeage de [best]
# 47       True                                     Copia [side_a]
# 48       True                                     Copia [side_b]

# %% [markdown]
# **Procedimiento de selección de variables**
#
# Para eliminar del dataset variables que no aportan información seguimos la siguiente secuecia:
# 1) Eliminamos los id de los casos individuales: [id] y [relid]
# 2) Eliminamos las variables que representan una versión alternativa de otra:\
#    [year] está implícita en [date_start]\
#    [conflict_dset_id], [conflict_new_id] son versiones de [conflict_name]\
#    [dyad_dset_id], [dyad_new_id] son versiones de [dyad_name]\
#    [side_a_dset_id], [side_a_new_id] y [gwnoa] son versiones de [side_a]\
#    [side_b_dset_id], [side_b_new_id] y [gwnob] son versiones de [side_b]\
#    [where_description] es un detalle de alta cardinalidad en texto abierto de [where_coordinates] (ej. Kabul international airport -> Kabul airport (Abbey gate entrance))\
#    [geom_wkt] es la concatenación de [longitude] y [latitude]\
#    [country_id] es otra versión de [country]\
# 4) Eliminamos variables con un valor único: [code_status]
# 5) Eliminamos variables con target leakage de [best]:\
#    [deaths_a], [deaths_b], [deaths_civilians], [deaths_unknown], [high] y [low] no estarían disponibles en un escenario real y conducen a [best]
# 6) Eliminamos variables de texto abierto vinculadas con las fuentes del los datos de mortalidad:\
#    [source_article], [source_office], [source_date], [source_headline], [source_original]
